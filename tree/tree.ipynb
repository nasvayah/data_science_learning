# %%
import pandas as pd
import numpy as np 
from sklearn import tree

# %%
df = pd.read_csv('cats.csv', index_col=0)
df
# Out:
#    Шерстист  Гавкает  Лазает по деревьям      Вид
# 0         1        1                   0  собачка
# 1         1        1                   0  собачка
# 2         1        1                   0  собачка
# 3         1        1                   0  собачка
# 4         1        0                   1    котик
# 5         1        0                   1    котик
# 6         1        0                   1    котик
# 7         1        0                   1    котик
# 8         1        1                   1    котик
# 9         0        0                   1    котик

# %%
df['Вид'] = [1 if name == 'собачка' else 0 for name in df['Вид']]
df
# Out:
#    Шерстист  Гавкает  Лазает по деревьям  Вид
# 0         1        1                   0    1
# 1         1        1                   0    1
# 2         1        1                   0    1
# 3         1        1                   0    1
# 4         1        0                   1    0
# 5         1        0                   1    0
# 6         1        0                   1    0
# 7         1        0                   1    0
# 8         1        1                   1    0
# 9         0        0                   1    0

# %%
X = df.iloc[:, 1:2]
y = df.iloc[:, 3]
X
# Out:
#    Гавкает
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
# 5        0
# 6        0
# 7        0
# 8        1
# 9        0

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf.fit(X, y)
y_predict = clf.predict(X)

# %%
tree.plot_tree(clf, feature_names=X.columns)
# Out:
# [Text(0.5, 0.75, 'Гавкает <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.625, 0.5, '  False')]
